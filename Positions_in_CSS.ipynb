# %% [markdown]
# Positions in CSS

# %%
#Task 1:Problem Statement

Write code to position 5 equal-sized (50 X 50px) boxes A, B, C, D, and E as follows:
1. box A 200px from the left, and 200px from the top of the viewportH
2. box B -30px left, and -30px above from the center of box A.
3. box B -30px right, and -30px above from the center of box A.
4. box B -30px left, and -30px below from the center of box A.
5. box B -30px right, and -30px below from the center of box A.

'''
<!DOCTYPE html>
<html lang="en">
<head>
  <meta charset="UTF-8">
  <meta name="viewport" content="width=device-width, initial-scale=1.0">
  <title>Box Positioning</title>
  <link rel="stylesheet" href="style.css">
</head>
<body>
  <div id="A" class="box">A</div>
  <div id="B" class="box">B</div>
  <div id="C" class="box">C</div>
  <div id="D" class="box">D</div>
  <div id="E" class="box">E</div>
</body>
</html>

CSS

.box {
  width: 50px;
  height: 50px;
  background-color: aquamarine;
  text-align: center;
  line-height: 50px;
  position: absolute;
  font-weight: bold;
}

/* Box A */
#A {
  left: 200px;
  top: 200px;
}

/* Center of A = (225px, 225px) */

/* Box B: -30px left, -30px above center of A */
#B {
  left: calc(225px - 30px - 25px);  /* 170px */
  top: calc(225px - 30px - 25px);   /* 170px */
}

/* Box C: +30px right, -30px above center of A */
#C {
  left: calc(225px + 30px - 25px);  /* 230px */
  top: calc(225px - 30px - 25px);   /* 170px */
}

/* Box D: -30px left, +30px below center of A */
#D {
  left: calc(225px - 30px - 25px);  /* 170px */
  top: calc(225px + 30px - 25px);   /* 230px */
}

/* Box E: +30px right, +30px below center of A */
#E {
  left: calc(225px + 30px - 25px);  /* 230px */
  top: calc(225px + 30px - 25px);   /* 230px */
}

'''


#Task 2:Problem Statement

Explain the difference between Absolute and Relative positioning.

"""
With relative positioning, that space is held for it. So even if you move the element
with top/left CSS, the space it was meant to be in is left untouched.
However, when you assign absolute positioning, it is taken out of this stack and everything
below it moves in to take its place. It is on its own separate layer and does not affect
the page anymore. It is positioned based on the closest parent that has relative positioning.

"""
#Task 3:Problem Statement

Create a card as shown in the picture below. (You can use CSS float property only for layout).

 '''
<!DOCTYPE html>
<html lang="en">
<head>
  <meta charset="UTF-8">
  <meta name="viewport" content="width=device-width, initial-scale=1.0">
  <title>Task 3 - Card Layout</title>
  <link rel="stylesheet" href="style.css">
</head>
<body>
  <div class="card">
    <div class="text-content">
      <h3>The Earth!!!</h3>
      <p>
        Nature is Earth's masterpiece, a symphony of life composed through millennia.
        Its landscapes whisper tales of ancient mountains, winding rivers, and flourishing forests,
        reminding us of the planet's boundless beauty. From delicate petals to towering redwoods,
        nature's artistry stirs awe and reconnects us to the essence of existence. Nature is Earth's
        masterpiece, a symphony of life composed through millennia. Its landscapes whisper tales of
        ancient mountains, winding rivers, and flourishing forests.
      </p>
    </div>

    <img src="https://img.freepik.com/free-photo/landscape-with-lake-sunset_395237-259.jpg?semt=ais_hybrid&w=740&q=80" alt="Nature Image" class="card-img">
  </div>
</body>
</html>

CSS

body {
  font-family: Arial, sans-serif;
  background-color: #fafafa;
  margin: 40px;
}

.card {
  width: 900px;
  background-color: #f5f5dc;
  border: 2px solid #000;
  padding: 20px;
  overflow: hidden; }

.card-img {
  width: 250px;
  height: 150px;
  float: right;
  margin-left: 20px;
}

.text-content {
  float: left;
  width: calc(100% - 270px);
}

h3 {
  margin-top: 0;
  color: #333;
  font-weight: bold;
}


 '''

 #4 Task 4:Problem Statement

Create a simple header that sticks to the top of a webpage upon scrolling.

'''
<!DOCTYPE html>
<html lang="en">
<head>
  <meta charset="UTF-8">
  <meta name="viewport" content="width=device-width, initial-scale=1.0">
  <title>Sticky Header</title>
  <link rel="stylesheet" href="style.css">
</head>
<body>
  <header class="navbar">
    <div class="logo">LOGO</div>
    <nav class="nav-links">
      <a href="#">Home</a>
      <a href="#">Pricing</a>
      <a href="#">Contact</a>
      <a href="#">Terms and Condition</a>
      <button class="btn">Get Started</button>
    </nav>
  </header>

  <main class="content">
    <h2>Heading 1</h2>
    <p>Lorem ipsum dolor sit amet consectetur adipisicing elit. Ipsum possimus modi magni deleniti rerum provident minima nisi cum delectus
       inventore, facere corrupti reprehenderit magnam ipsa...</p>

    <h2>Heading 2</h2>
    <p>Lorem ipsum dolor sit amet consectetur adipisicing elit. Ipsum possimus modi magni deleniti rerum provident minima nisi cum delectus...</p>

    <h3>Heading 3</h3>
    <p>
      Lorem ipsum dolor Lorem ipsum dolor sit amet consectetur adipisicing elit. Molestiae aliquam consequatur est repellat aliquid laudantium
      aut sit. Facilis aut tempora velit, quos vero quis eligendi iure facere dolore. Quis, ea!
      Lorem ipsum dolor sit amet consectetur adipisicing elit. Et, labore asperiores eius placeat consequuntur, non perferendis laudantium
      voluptatum, quia nihil similique temporibus ad? Inventore nisi laudantium esse et, tempore consequatur Lorem, ipsum dolor sit amet
      consectetur adipisicing elit. Labore corporis consequatur eveniet blanditiis ipsam commodi excepturi tenetur illo, quas dolorum saepe
      eius aliquid provident architecto porro est! Quo, animi facilis.
     Lorem ipsum dolor sit amet consectetur adipisicing elit. Quae quis nostrum nam commodi consequuntur, quibusdam vel deleniti delectus
    ad quasi accusantium animi architecto hic atque quas et illo ipsum obcaecati.
    t amet consectetur adipisicing elit. Ipsum possimus modi magni deleniti rerum provident minima nisi cum delectusLorem ipsum dolor Lorem ipsum dolor sit amet consectetur adipisicing elit. Molestiae aliquam consequatur est repellat aliquid laudantium
      aut sit. Facilis aut tempora velit, quos vero quis eligendi iure facere dolore. Quis, ea!
      Lorem ipsum dolor sit amet consectetur adipisicing elit. Et, labore asperiores eius placeat consequuntur, non perferendis laudantium
      voluptatum, quia nihil similique temporibus ad? Inventore nisi laudantium esse et, tempore consequatur Lorem, ipsum dolor sit amet
      consectetur adipisicing elit. Labore corporis consequatur eveniet blanditiis ipsam commodi excepturi tenetur illo, quas dolorum saepe
      eius aliquid provident architecto porro est! Quo, animi facilis.
     Lorem ipsum dolor sit amet consectetur adipisicing elit. Quae quis nostrum nam commodi consequuntur, quibusdam vel deleniti delectus
    ad quasi accusantium animi architecto hic atque quas et illo ipsum obcaecati.
    t amet consectetur adipisicing elit. Ipsum possimus modi magni deleniti rerum provident minima nisi cum delectusLorem ipsum dolor Lorem ipsum dolor sit amet consectetur adipisicing elit. Molestiae aliquam consequatur est repellat aliquid laudantium
      aut sit. Facilis aut tempora velit, quos vero quis eligendi iure facere dolore. Quis, ea!
      Lorem ipsum dolor sit amet consectetur adipisicing elit. Et, labore asperiores eius placeat consequuntur, non perferendis laudantium
      voluptatum, quia nihil similique temporibus ad? Inventore nisi laudantium esse et, tempore consequatur Lorem, ipsum dolor sit amet
      consectetur adipisicing elit. Labore corporis consequatur eveniet blanditiis ipsam commodi excepturi tenetur illo, quas dolorum saepe
      eius aliquid provident architecto porro est! Quo, animi facilis.
     Lorem ipsum dolor sit amet consectetur adipisicing elit. Quae quis nostrum nam commodi consequuntur, quibusdam vel deleniti delectus
    ad quasi accusantium animi architecto hic atque quas et illo ipsum obcaecati.
    t amet consectetur adipisicing elit. Ipsum possimus modi magni deleniti rerum provident minima nisi cum delectus...</p>
  </main>
</body>
</html>

CSS

/* Reset and base styles */
body {
  font-family: Arial, sans-serif;
  margin: 0;
  padding: 0;
}

/* Header styling */
.navbar {
  position: sticky;       /* Keeps header at the top while scrolling */
  top: 0;
  background-color: #333; /* Dark background */
  color: white;
  display: flex;
  justify-content: space-between;
  align-items: center;
  padding: 10px 40px;
  z-index: 1000;          /* Ensures header stays above content */
}

/* Logo */
.logo {
  font-size: 1.2em;
  font-weight: bold;
}

/* Navigation links */
.nav-links a {
  color: white;
  text-decoration: none;
  margin: 0 15px;
  font-size: 16px;
  transition: color 0.3s;
}

.nav-links a:hover {
  color: #f5c542;
}

/* Button styling */
.btn {
  background-color: #f5c542;
  color: black;
  border: none;
  padding: 8px 15px;
  border-radius: 5px;
  cursor: pointer;
  font-weight: bold;
}

.btn:hover {
  background-color: #ffdb58;
}

/* Page content */
.content {
  padding: 30px 40px;
  line-height: 1.6;
}


'''

#5

'''
Z-index is a property in CSS which is used to prioritize the stacking context. Here stacking context means layering of each HTML elements
 in the z-direction i.e. in the direction you view the viewport/window.The higher the z-index value, the closer to the viewer the element is.

 <!DOCTYPE html>
<html lang="en">
<head>
  <meta charset="UTF-8">
  <meta name="viewport" content="width=device-width, initial-scale=1.0">
  <title>Z-Index Example</title>
  <link rel="stylesheet" href="style.css">
</head>
<body>
  <div class="box box1">Box 1</div>
  <div class="box box2">Box 2</div>
  <div class="box box3">Box 3</div>
</body>
</html>

CSS

body {
  background-color: #f4f4f4;
}

.box {
  width: 150px;
  height: 150px;
  position: absolute;
  text-align: center;
  line-height: 150px;
  font-weight: bold;
  color: white;
  font-family: Arial, sans-serif;
}

/* Box 1 - bottom layer */
.box1 {
  background-color: red;
  top: 50px;
  left: 50px;
  z-index: 1;
}

/* Box 2 - middle layer */
.box2 {
  background-color: blue;
  top: 100px;
  left: 100px;
  z-index: 2;
}

/* Box 3 - top layer */
.box3 {
  background-color: green;
  top: 150px;
  left: 150px;
  z-index: 3;
}


'''
